# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from tqdm import tqdm
import cv2
import os 

import random 
from scipy.spatial import distance

#pca and truncatedSVD for dimensionality reduction
from sklearn.decomposition import PCA, TruncatedSVD

from sklearn.manifold import TSNE

import keras
from keras.preprocessing import image
from keras.applications.imagenet_utils import decode_predictions, preprocess_input
from keras.models import Model

# %matplotlib notebook

# %%
#dowloading data for feature extraction
model = keras.applications.VGG16(weights='imagenet', include_top=True)
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\kubas\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\kubas\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\kubas\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\kubas\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\kubas\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# ...

# %%
def convert_image(image):
    ''' Changes BGR to RGB'''
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

def show_image(image, title):
    plt.clf()
    plt.imshow(convert_image(image))
    plt.axis("off")
    plt.title(title)
    plt.show()

metadata = pd.read_csv('paintings.csv', sep='&', encoding='utf-8')
DATADIR = 'C:/Users/kubas/Desktop/paintings/'
def get_image_path_by_label(label):
    return os.path.join(DATADIR,str(metadata[metadata['Title'] == label].values[0, 3])+".jpg")

# get_image_path_by_label("Ostrzenie noży")

# %%
#loading numpy arrays 
X = np.load('X_data.npy')
labels = np.load('labels_data.npy')

# %%
#feature extraction
feat_extractor = Model(inputs=model.input, outputs=model.get_layer("fc2").output)
#feat_extractor.summary()

# %%
#using pre-trained "extractor"
feat = feat_extractor.predict(X[:1])

# %%
# plot of activations in last layer "fc2"
plt.figure(figsize=(16,4))
plt.plot(feat[0])

# %%
# #extracting features for every image
# features = []
# for x in tqdm(X):
#     features.append(feat_extractor.predict(np.expand_dims(x, 0))[0])
# features = np.array(features)

#saving features 
#np.save("extracted_features_vgg16,npy",features)

features = np.load("extracted_features_vgg16.npy")

# %% [markdown]
# ## Method - PCA (Principal Component Analysis)

# %%
def get_image(url):
    ''' 
    downloads from local file and prepares to use in reverse search, 
    in case of use in show_image() add [0, :, :, :] to delete batch dimension
    '''
    image =  cv2.resize(cv2.imread(os.path.join(url)), (224, 224))
    return np.array(image).reshape(-1, 224, 224, 3)


def PCA_get_closest_to_image(image, N=5):
    """
    input is straight numpy array (not features array)
    returns N closest images indexes
    """
    new_pca_features = pca.transform(feat_extractor.predict(image))[0]
    distances = [ distance.cosine(new_pca_features, feat) for feat in pca_features ]
    return sorted(range(len(distances)), key=lambda k: distances[k])[0:N] 

def LSA_get_closest_to_image(image, N=5):
    """
    input is straight numpy array (not features array)
    returns N closest images indexes
    """
    new_lsa_features = lsa.transform(feat_extractor.predict(image))[0]
    distances = [ distance.cosine(new_lsa_features, feat) for feat in lsa_features ]
    return sorted(range(len(distances)), key=lambda k: distances[k])[0:N] 

def compare_view(image, N=5):
    pass

# %%
#we applay PCA and then we keep 300 top principal components
pca = PCA(n_components=300)
pca.fit(features)
pca_features = pca.transform(features)

# %%
#showing random image and closest to it ;]
n = random.randint(0, 1800)
show_image(X[n], labels[n])

print("\n")

for idx in PCA_get_closest_to_image(np.expand_dims(X[n], 0))[1:]:
    show_image(X[idx], title = str(labels[idx]))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Method for visualization - t-SNE (t-distributed Stochastic Neighbor Embedding)

# %%
tsne = TSNE(n_components=2)
#using PCA top components (t-SNE doesn't like big number of featurers)
tsne_features = tsne.fit_transform(pca_features)

# %%
tx, ty = tsne_features[:,0], tsne_features[:,1]
tx = (tx-np.min(tx)) / (np.max(tx) - np.min(tx))
ty = (ty-np.min(ty)) / (np.max(ty) - np.min(ty))

# %%
# from PIL import Image
width = 4000
height = 3000
max_dim = 100

full_image = Image.new('RGBA', (width, height))
iter = 0
for x, y in zip(tx, ty):
    tile = Image.open(get_image_path_by_label(labels[iter]))
    rs = max(1, tile.width/max_dim, tile.height/max_dim)
    tile = tile.resize((int(tile.width/rs), int(tile.height/rs)), Image.ANTIALIAS)
    full_image.paste(tile, (int((width-max_dim)*x), int((height-max_dim)*y)), mask=tile.convert('RGBA'))
    iter += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-66c52cc0e6df> in <module>
#      12     full_image.paste(tile, (int((width-max_dim)*x), int((height-max_dim)*y)), mask=tile.convert('RGBA'))
#      13     iter += 1
# ---> 14 matplotlib.pyplot.figure(figsize = (16,12))
#      15 imshow(full_image)
#
# NameError: name 'matplotlib' is not defined

# %%
full_image.save("tSNE.png")

# %% [markdown]
# ## Method - TruncatedSVD (LSA)

# %%
lsa = TruncatedSVD(n_components=100, algorithm='arpack') #arpack, randomized <- algorithms
lsa_features = lsa.fit_transform(features)

# %%
show_image(X[n], labels[n])

print("\n")

for idx in LSA_get_closest_to_image(np.expand_dims(X[n], 0))[1:]:
    show_image(X[idx], title = str(labels[idx]))
